# %% [markdown]
# # CS 171 / EE 142 Problem Set 2
# # Due Friday, April 24, 2026 @ 11:59pm

# %% [markdown]
# ## Read *all* cells carefully and answer all parts (both text and missing code)

# %% [markdown]
# ### Enter your information below:
#
# <div style="color: #000000;background-color: #EEEEFF">
#     Your Name (submitter): <br>
# Your student ID (submitter):
#
# <b>By submitting this notebook, I assert that the work below is my own work, completed for this course.  Except where explicitly cited, none of the portions of this notebook are duplicated from anyone else's work or my own previous work.</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#     <font size=+2>Total Problem Set Grading</font> (to be completed by grader)<br>
#     Total Points: /20<br>
#     Late Days Used on this Assignment: <br>
#     Total Late Days Used: <br>
# </div>

# %% [markdown]
# <div style="color: #000000;background-color: #FFEEDD">
# <h2>Overview</h2>
#
# In this problem set, We will be using data on house sales in Ames, Iowa.  Data documentation can be found at http://jse.amstat.org/v19n3/decock/DataDocumentation.txt
# The data have been modified for this problem:
# - A few outliners have been removed.
# - Categorical variables have been removed.
# - The data have been "z-normalized:" each feature has been scaled and shifted so that "0" is the average value and the magnitude is the number of standard deviations from the mean value.  We will learn more about this later.  For now, just note that the average value of each feature is 0.
# - The data have been split randomly into training and testing data.
#
# The code below loads in the variables:
# - `trainX` is the standard training data matrix.
# - `testX` is the corresponding data matrix for the testing data.
# - `trainYreg` is the target for the regression problems: the sale price for the home, in thousands of dollars
# - `trainYclass` is the target for the classification problems: -1 if the sale price is less than 150,000 and +1 if the sale price is greater than 150,000
# - `testYreg` and `testYclass` are the same for the testing set
# - `featurenames` are the names of the features (not needed)
#
# Note that an initial "column of all ones" has been added to `trainX` and `testX` already.
# </div>

# %%
# no other libraries are to be imported!
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

vars = np.load('/usr/local/cs171/amesmod.npz',allow_pickle=True)
for k in vars.keys():
    exec(f"{k} = vars['{k}']")

# %% [markdown]
# <div style="color: #000000;background-color: #FFEEFF">
#     <font size=+2>Part I: Linear Regression</font>
# </div>

# %% [markdown]
# <div style="color: #000000;background-color: #FFFFEE">
#     <font size=+2>Question 1:</font> <font size=+1>(3 points)</font>
# Complete the training and testing functions below for linear least squares.</div>
# <div class="alert alert-success">
#     <font size=+1>Grading</font> (to be completed by grader)<br>
#     Score: /3<br>
# </div>

# %%
def learnlls(X,Y):
    # X is the data matrix of shape (m,n)
    # Y is are the target values of shape (m,)
    # function should return w of shape (n,)
    
    #your code here
    pass # <--- remove
    
def predictlls(X,w):
    # X is the (testing) data of shape (m,n)
    # w are the weights learned in linear least-squares regression of shape (n,)
    # function should return Y, the predicted values of shape (m,)
   
    # your code here
    pass # <--- remove
    
def testlls(X,Y,w):
    # X and Y are the testing data
    # w are the weights from linear least-squares regression
    # returns the root mean squared error (that is, the square root of the average squared error)
    Ydelta = Y - predictlls(X,w)
    return np.sqrt((Ydelta*Ydelta).mean())

# %%
# now code to check the training and testing errors:
wreg = learnlls(trainX,trainYreg)
print('training RMSE: ',testlls(trainX,trainYreg,wreg))
print('testing RSME:  ',testlls(testX,testYreg,wreg))

# %% [markdown]
# <div style="color: #000000;background-color: #FFEEFF">
#     <font size=+2>Part II: Logistic Regression</font>
# </div>

# %% [markdown]
# <div style="color: #000000;background-color: #FFFFEE">
#     <font size=+2>Question 2:</font> <font size=+1>(8 points)</font>
#
# Okay, now we will do the same for classification using logistic regression.
#
# Complete the training and testing functions below for logistic regression.  We will use a constant step size of $10^{-6}$ (aka `1e-6`).  Picking a good step size is tricky, but this one should work well for this assignment.  Start $w$ at 0 (yes, sometimes this isn't a good choice, but for logistic regression, it is fine).  Use **batch** (or standard) gradient descent.  (Stochastic gradient descent is harder to tell whether it is converging.)  Stop when the *total loss* function does not improve by more than $10^{-4}$ (aka `1e-4`) after a step.
#
# A few hints:
# - This function will work much faster if the only loop is over iterations of gradient descent; no loops over data. (my code takes under a minute to execute the training and testing error cell, below).
# - You can use `print` to output debugging information (or even use pyplot to plot things!).  The line `clear_output(wait=True)` will clear the output, in case you don't want the cell's output to extend too far during debugging.  (please remove debugging output when submitting)
# - To check to see if it is working, you should look that the gradient is getting smaller, but (more importantly) that the objective function (the loss) is getting smaller.
#
# </div>
#    <div class="alert alert-success">
#     <font size=+1>Grading</font> (to be completed by grader)<br>
#     Score: /8<br>
# </div>

# %%
def learnlogreg(X,Y):
    # X is the data matrix of shape (m,n)
    # Y is are the target labels (+1,-1) of shape (m,)
    # function should return w of shape (n,)
    
    ## your code here
    pass # <-- remove
        
def predictlogreg(X,w):
    # X is the (testing) data of shape (m,n)
    # w are the weights learned in logistic regression
    # function should return Y, the predicted values of shape (m,) (all values either +1 or -1)
    
    ## your code here
    pass # <-- remove
    
def testlogreg(X,Y,w):
    # X and Y are the testing data
    # w are the weights from logistic regression
    # returns the mean squared error
    Ypred = np.sign(predictlogreg(X,w)) ## should be +1/-1, but in case they are not
    
    return (Ypred!=np.sign(Y)).mean()

# %%
# %%time
# now code to check the training and testing errors:
wclass = learnlogreg(trainX,trainYclass)
print('training classification error rate: ',testlogreg(trainX,trainYclass,wclass))
print('testing classification error rate:  ',testlogreg(testX,testYclass,wclass))

# %% [markdown]
# <div style="color: #000000;background-color: #FFEEFF">
#     <font size=+2>Part III: Added Features</font>
# </div>

# %% [markdown]
# <div style="color: #000000;background-color: #EEFFFF">
#     In this part we are going to see if we can add features to improve things.  While everything here would also work with logistic regression, it would take longer (and benefit from some changes to the learning rates).  So, for this part, we will return to just <b>linear least squares</b>.
#     <p>
#     Consider adding the following features:
#         <ul>
#             <li>(A) raw: no added features (the same as part I)</li>
#             <li>(B) +indicators: adding 1 extra feature for each original feature (not including the "constant") -- specifically, the value 1 if the original feature is greater than 0 and value 0 otherwise</li>
#             <li>(C) +squares: adding 1 extra feature for each original feature (not including the "constant") -- specifically that feature squared</li>
#             <li>(D) +indicators+squares: adding both sets of features above</li>
#             <li>(E) +second-order: adding all second order terms of the original features (that is, all squares and pair-wise multiplications)</li>
#         </ul>
# </div>

# %% [markdown]
# <div style="color: #000000;background-color: #FFFFEE">
#     <font size=+2>Question 3:</font> <font size=+1>(5 points)</font>
#
# For each of the feature sets above, report: number of features (including constant feature), the training root mean squared error, and the testing root mean squared error.
#
# Report your results in a table like
#
# <tt>
# A n=99 training: 123.456 testing: 123.456<br>
# B n=99 training: 123.456 testing: 123.456<br>
# C n=99 training: 123.456 testing: 123.456<br>
# D n=99 training: 123.456 testing: 123.456<br>
# E n=99 training: 123.456 testing: 123.456<br>
# </tt>
# (except, with each "99" or "123.456" replaced with the correct values)
#
# </div>
#    <div class="alert alert-success">
#     <font size=+1>Grading</font> (to be completed by grader)<br>
#     Score: /5<br>
# </div>

# %%
## your code here

# %% [markdown]
# <div style="color: #000000;background-color: #FFFFEE">
#     <font size=+2>Question 4:</font> <font size=+1>(4 points)</font>
#     <p>
#         Consider the results from question 3.  Answer in terms of concepts from class, but no equations are necessary.
#     </p>
#     <p>
#         a. How does the training error change with the number of features?<br>
#         b. How does the testing error relate to the training error for any fixed number of features?<br>
#         c. How does the testing error change with the number of features?<br>
# </div>
#    <div class="alert alert-success">
#     <font size=+1>Grading</font> (to be completed by grader)<br>
#     Score: /4<br>
# </div>

# %% [markdown]
# ### Your answers here
# a.
#
# b.
#
# c.
